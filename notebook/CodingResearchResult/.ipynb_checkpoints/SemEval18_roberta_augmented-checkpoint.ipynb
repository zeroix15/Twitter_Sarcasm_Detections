# %%
# install required packages
# !pip install -q transformers
# !pip install -q simpletransformers
# !pip install -q kaggle
# !pip install -q nlpaug
# Out:
#      |████████████████████████████████| 2.6 MB 27.1 MB/s
#      |████████████████████████████████| 895 kB 52.6 MB/s
#      |████████████████████████████████| 3.3 MB 56.9 MB/s
#      |████████████████████████████████| 636 kB 60.2 MB/s
#      |████████████████████████████████| 221 kB 40.5 MB/s
#      |████████████████████████████████| 76 kB 5.2 MB/s
#      |████████████████████████████████| 542 kB 58.0 MB/s
#      |████████████████████████████████| 124 kB 19.7 MB/s
#      |████████████████████████████████| 1.2 MB 55.2 MB/s
#      |████████████████████████████████| 43 kB 2.3 MB/s
#      |████████████████████████████████| 7.9 MB 67.0 MB/s
#      |████████████████████████████████| 1.8 MB 57.2 MB/s
#      |████████████████████████████████| 170 kB 64.1 MB/s
#      |████████████████████████████████| 97 kB 7.8 MB/s
#      |████████████████████████████████| 138 kB 67.8 MB/s
#      |████████████████████████████████| 133 kB 71.1 MB/s
#      |████████████████████████████████| 63 kB 2.2 MB/s
#      |████████████████████████████████| 62 kB 932 kB/s
#      |████████████████████████████████| 243 kB 65.2 MB/s
#      |████████████████████████████████| 118 kB 68.4 MB/s
#      |████████████████████████████████| 4.2 MB 66.2 MB/s
#      |████████████████████████████████| 75 kB 1.9 MB/s
#      |████████████████████████████████| 111 kB 72.5 MB/s
#      |████████████████████████████████| 122 kB 68.4 MB/s
#      |████████████████████████████████| 786 kB 64.6 MB/s
#      |████████████████████████████████| 368 kB 67.8 MB/s
#   Building wheel for subprocess32 (setup.py) ... done
#   Building wheel for pathtools (setup.py) ... done
#   Building wheel for seqeval (setup.py) ... done
#   Building wheel for blinker (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jupyter-console 5.2.0 requires prompt-toolkit<2.0.0,>=1.0.0, but you have prompt-toolkit 3.0.19 which is incompatible.
# google-colab 1.0.0 requires ipykernel~=4.10, but you have ipykernel 6.0.3 which is incompatible.
# google-colab 1.0.0 requires ipython~=5.5.0, but you have ipython 7.25.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
#      |████████████████████████████████| 405 kB 35.9 MB/s

# %%
import seaborn as sns

import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np

from sklearn.model_selection import train_test_split

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
  
# Then move kaggle.json into the folder where the API expects to find it.
# !mkdir -p ~/.kaggle/ && mv kaggle.json ~/.kaggle/ && chmod 600 ~/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-dbc6454c-9efc-42f5-9c8b-c4eb66830940" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbc6454c-9efc-42f5-9c8b-c4eb66830940">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 70 bytes

# %%
# !kaggle datasets download -d rtatman/glove-global-vectors-for-word-representation
# Out:
# Downloading glove-global-vectors-for-word-representation.zip to /content
#  98% 451M/458M [00:04<00:00, 81.2MB/s]
# 100% 458M/458M [00:04<00:00, 113MB/s]

# %%
! unzip /content/glove-global-vectors-for-word-representation.zip
# Out:
# Archive:  /content/glove-global-vectors-for-word-representation.zip
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.50d.txt

# %%
# Import Modules
import csv
import urllib.request

# %%
# Download dataset
train_url="https://raw.githubusercontent.com/zeroix15/Twitter_Sarcasm_Detections/main/semeval18/train_cleaned.csv"
validation_url="https://raw.githubusercontent.com/zeroix15/Twitter_Sarcasm_Detections/main/semeval18/test_cleaned.csv"


#rain_url="https://raw.githubusercontent.com/zeroix15/Twitter_Sarcasm_Detections/main/text/train.csv"
#validation_url="https://raw.githubusercontent.com/zeroix15/Twitter_Sarcasm_Detections/main/text/dev.csv"
#test_url="https://raw.githubusercontent.com/zeroix15/Twitter_Sarcasm_Detections/main/text/test.csv"

# %%
import pandas as pd
train_df = pd.read_csv(train_url)
validate_df = pd.read_csv(validation_url)

train_df.columns = ["tweet_text","sarcasm_label"]
validate_df.columns = ["tweet_text","sarcasm_label"]


train_df.head(5)
# Out:
#                                           tweet_text  sarcasm_label
# 0                      gotta go back to work tonight              0
# 1  a romantic candlelit dinner for two would cost...              1
# 2  lol drunk mom on christmas is so fun .   this ...              1
# 3   few politicians get importance of patient dig...              1
# 4   gerrymandering neither party will give up . i...              0

# %%
x=train_df.sarcasm_label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('samples')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'samples')

# %%
print('Shape of df train',train_df.shape)
# Out:
# Shape of df train (3775, 2)

# %%
import nlpaug.augmenter.char as nac
import nlpaug.augmenter.word as naw
import nlpaug.augmenter.sentence as nas
import nlpaug.flow as naf

from nlpaug.util import Action

#aug = naw.ContextualWordEmbsAug(
#    model_path='bert-base-uncased', action="insert")

aug_w2v = naw.WordEmbsAug(
    model_type='glove', model_path='/content/glove.6B.100d.txt',
    action="substitute")

# %%
text = train_df.iloc[0]['tweet_text']
text
# Out:
# 'gotta go back to work tonight'

# %%
aug_w2v.aug_p=0.01
print("Augmented Text:")
for ii in range(3):
    augmented_text = aug_w2v.augment(text)
    print(augmented_text)
# Out:
# Augmented Text:
# gotta go pull to work tonight
# gotta go back to work i
# gotta go back to work play

# %%
#train,valid=train_test_split(train_df,test_size=0.15)
#print('Shape of train',train.shape)
#print("Shape of Validation ",valid.shape)

# %%
from sklearn.utils import shuffle

def augment_text(df,samples,pr=0.2):
    aug_w2v.aug_p=pr
    new_text=[]
    
    ##dropping samples from validation
    df_n=df[df.sarcasm_label==1].reset_index(drop=True)

    ## data augmentation loop
    for i in tqdm(np.random.randint(0,len(df_n),samples)):
        
            text = df_n.iloc[i]['tweet_text']
            augmented_text = aug_w2v.augment(text)
            new_text.append(augmented_text)
    
    
    ## dataframe
    new=pd.DataFrame({'tweet_text':new_text,'sarcasm_label':1})
    df=shuffle(df.append(new).reset_index(drop=True))
    return df

# %%
train_df = augment_text(train_df,samples=15)   ## change samples to 0 for no augmentation
#train_df = train.append(valid).reset_index(drop=True)
# Out:
# 100%|██████████| 15/15 [00:01<00:00,  9.72it/s]

# %%
x=train_df.sarcasm_label.value_counts()
sns.barplot(x.index,x)
plt.gca().set_ylabel('samples')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0, 0.5, 'samples')

# %%
train_df.to_csv(r'/content/augmentedtrain.csv', index = False)

# %%
train_args = {
    'reprocess_input_data': True,
    'overwrite_output_dir': True,
    'sliding_window': False,
    'max_seq_length': 40,
    'learning_rate': 0.00001,
    'weight_decay': 0.01,
    'warmup_ratio': 0.2,
    'max_grad_norm': 1.0,
    'num_train_epochs': 13,
    'train_batch_size': 16, 
    'save_model_every_epoch': False,
    'fp16': True,
    'manual_seed': 128,
    'output_dir': '/outputs/',
    'evaluate_during_training': True,
}

# %%
from simpletransformers.classification import ClassificationModel
import pandas as pd
import logging
import sklearn

logging.basicConfig(level=logging.DEBUG)
transformers_logger = logging.getLogger('transformers')
transformers_logger.setLevel(logging.WARNING)

# We use the RoBERTa base pre-trained model.
model = ClassificationModel('roberta', 'roberta-base', num_labels=2, args=train_args) 

# Train the model, use the validation set as the development set as per the paper.
# When training to 1 epoch this is not that essential, however, if you decide to 
# train more and configure early stopping, do check out the simple transformers
# documentation: https://simpletransformers.ai/docs/tips-and-tricks/#using-early-stopping
model.train_model(train_df, eval_df=validate_df)
result, model_outputs, wrong_predictions = model.eval_model(validate_df, acc=sklearn.metrics.accuracy_score)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/config.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140049884732304 on /root/.cache/huggingface/transformers/733bade19e5f0ce98e6531021dd5180994bb2f7b8bd7e80c7968805834ba351e.35205c6cfc956461d8515139f0f8dd5d207a2f336c0c3a83b4bc8dca3518e37b.lock
# INFO:filelock:Lock 140049884732304 acquired on /root/.cache/huggingface/transformers/733bade19e5f0ce98e6531021dd5180994bb2f7b8bd7e80c7968805834ba351e.35205c6cfc956461d8515139f0f8dd5d207a2f336c0c3a83b4bc8dca3518e37b.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-base/resolve/main/config.json HTTP/1.1" 200 481
# Downloading:   0%|          | 0.00/481 [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140049884732304 on /root/.cache/huggingface/transformers/733bade19e5f0ce98e6531021dd5180994bb2f7b8bd7e80c7968805834ba351e.35205c6cfc956461d8515139f0f8dd5d207a2f336c0c3a83b4bc8dca3518e37b.lock
# INFO:filelock:Lock 140049884732304 released on /root/.cache/huggingface/transformers/733bade19e5f0ce98e6531021dd5180994bb2f7b8bd7e80c7968805834ba351e.35205c6cfc956461d8515139f0f8dd5d207a2f336c0c3a83b4bc8dca3518e37b.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/pytorch_model.bin HTTP/1.1" 302 0
# DEBUG:filelock:Attempting to acquire lock 140046782551184 on /root/.cache/huggingface/transformers/51ba668f7ff34e7cdfa9561e8361747738113878850a7d717dbc69de8683aaad.c7efaa30a0d80b2958b876969faa180e485944a849deee4ad482332de65365a7.lock
# INFO:filelock:Lock 140046782551184 acquired on /root/.cache/huggingface/transformers/51ba668f7ff34e7cdfa9561e8361747738113878850a7d717dbc69de8683aaad.c7efaa30a0d80b2958b876969faa180e485944a849deee4ad482332de65365a7.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): cdn-lfs.huggingface.co:443
# DEBUG:urllib3.connectionpool:https://cdn-lfs.huggingface.co:443 "GET /roberta-base/278b7a95739c4392fae9b818bb5343dde20be1b89318f37a6d939e1e1b9e461b HTTP/1.1" 200 501200538
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140046782551184 on /root/.cache/huggingface/transformers/51ba668f7ff34e7cdfa9561e8361747738113878850a7d717dbc69de8683aaad.c7efaa30a0d80b2958b876969faa180e485944a849deee4ad482332de65365a7.lock
# INFO:filelock:Lock 140046782551184 released on /root/.cache/huggingface/transformers/51ba668f7ff34e7cdfa9561e8361747738113878850a7d717dbc69de8683aaad.c7efaa30a0d80b2958b876969faa180e485944a849deee4ad482332de65365a7.lock
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaForSequenceClassification: ['lm_head.decoder.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.bias', 'lm_head.bias', 'lm_head.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.out_proj.weight', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /api/models/roberta-base HTTP/1.1" 200 929
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/vocab.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140046781865104 on /root/.cache/huggingface/transformers/d3ccdbfeb9aaa747ef20432d4976c32ee3fa69663b379deb253ccfce2bb1fdc5.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# INFO:filelock:Lock 140046781865104 acquired on /root/.cache/huggingface/transformers/d3ccdbfeb9aaa747ef20432d4976c32ee3fa69663b379deb253ccfce2bb1fdc5.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-base/resolve/main/vocab.json HTTP/1.1" 200 898823
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140046781865104 on /root/.cache/huggingface/transformers/d3ccdbfeb9aaa747ef20432d4976c32ee3fa69663b379deb253ccfce2bb1fdc5.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# INFO:filelock:Lock 140046781865104 released on /root/.cache/huggingface/transformers/d3ccdbfeb9aaa747ef20432d4976c32ee3fa69663b379deb253ccfce2bb1fdc5.d67d6b367eb24ab43b08ad55e014cf254076934f71d832bbab9ad35644a375ab.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/merges.txt HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140046781865872 on /root/.cache/huggingface/transformers/cafdecc90fcab17011e12ac813dd574b4b3fea39da6dd817813efa010262ff3f.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# INFO:filelock:Lock 140046781865872 acquired on /root/.cache/huggingface/transformers/cafdecc90fcab17011e12ac813dd574b4b3fea39da6dd817813efa010262ff3f.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-base/resolve/main/merges.txt HTTP/1.1" 200 456318
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140046781865872 on /root/.cache/huggingface/transformers/cafdecc90fcab17011e12ac813dd574b4b3fea39da6dd817813efa010262ff3f.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# INFO:filelock:Lock 140046781865872 released on /root/.cache/huggingface/transformers/cafdecc90fcab17011e12ac813dd574b4b3fea39da6dd817813efa010262ff3f.5d12962c5ee615a4c803841266e9c3be9a691a924f72d395d3a6c6c81157788b.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/tokenizer.json HTTP/1.1" 200 0
# DEBUG:filelock:Attempting to acquire lock 140046781864784 on /root/.cache/huggingface/transformers/d53fc0fa09b8342651efd4073d75e19617b3e51287c2a535becda5808a8db287.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# INFO:filelock:Lock 140046781864784 acquired on /root/.cache/huggingface/transformers/d53fc0fa09b8342651efd4073d75e19617b3e51287c2a535becda5808a8db287.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "GET /roberta-base/resolve/main/tokenizer.json HTTP/1.1" 200 1355863
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# DEBUG:filelock:Attempting to release lock 140046781864784 on /root/.cache/huggingface/transformers/d53fc0fa09b8342651efd4073d75e19617b3e51287c2a535becda5808a8db287.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# INFO:filelock:Lock 140046781864784 released on /root/.cache/huggingface/transformers/d53fc0fa09b8342651efd4073d75e19617b3e51287c2a535becda5808a8db287.fc9576039592f026ad76a1c231b89aee8668488c671dfbe6616bab2ed298d730.lock
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/added_tokens.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/special_tokens_map.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/tokenizer_config.json HTTP/1.1" 404 0
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): huggingface.co:443
# DEBUG:urllib3.connectionpool:https://huggingface.co:443 "HEAD /roberta-base/resolve/main/config.json HTTP/1.1" 200 0
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:616: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/3790 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_train_roberta_40_2_2
# Epoch:   0%|          | 0/13 [00:00<?, ?it/s]
# Running Epoch 0 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1402: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 1 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:942: FutureWarning: Non-finite norm encountered in torch.nn.utils.clip_grad_norm_; continuing anyway. Note that the default behavior will change in a future release to error out if a non-finite total norm is encountered. At that point, setting error_if_nonfinite=false will be required to retain the old behavior.
#   model.parameters(), args.max_grad_norm
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 2 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 3 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 4 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 5 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 6 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 7 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 8 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 9 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 10 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 11 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Epoch 12 of 13:   0%|          | 0/237 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# INFO:simpletransformers.classification.classification_model: Training of roberta model complete. Saved to /outputs/.
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Evaluation:   0%|          | 0/98 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.4183331753857281, 'tp': 228, 'tn': 324, 'fp': 146, 'fn': 81, 'auroc': 0.7714521793017972, 'auprc': 0.6795682374946422, 'eval_loss': 2.019063985317337, 'acc': 0.7086007702182285}

# %%
#f1-score
result, model_outputs, wrong_predictions = model.eval_model(validate_df, acc=sklearn.metrics.f1_score)
# Out:
# /usr/local/lib/python3.7/dist-packages/simpletransformers/classification/classification_model.py:1402: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   "Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels."
# INFO:simpletransformers.classification.classification_utils: Converting to features started. Cache is not used.
#   0%|          | 0/779 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_utils: Saving features into cached file cache_dir/cached_dev_roberta_40_2_2
# Running Evaluation:   0%|          | 0/98 [00:00<?, ?it/s]
# INFO:simpletransformers.classification.classification_model:{'mcc': 0.4183331753857281, 'tp': 228, 'tn': 324, 'fp': 146, 'fn': 81, 'auroc': 0.7714521793017972, 'auprc': 0.6795682374946422, 'eval_loss': 2.019063985317337, 'acc': 0.6676427525622255}
